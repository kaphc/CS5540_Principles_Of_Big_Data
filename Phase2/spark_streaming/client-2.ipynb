# %%
import findspark

findspark.init()

from pyspark import SparkContext
from pyspark.streaming import StreamingContext
from pyspark.sql import SQLContext
from pyspark.sql.functions import desc
import json
import pickle

sc = SparkContext()
ssc = StreamingContext(sc, 10)
sqlContext = SQLContext(sc)

socket_stream = ssc.socketTextStream("localhost", 9009)

lines = socket_stream.window(20,20)

lines.map( lambda text: text.split( "~@" ) ).foreachRDD(lambda rdd: rdd.toDF().registerTempTable("tweets"))

# %%
import time
from IPython import display
import matplotlib.pyplot as plt
import seaborn as sns
import pandas
# Only works for Jupyter Notebooks!
# %matplotlib inline

ssc.start()

# %%
from firebase import firebase

firebase = firebase.FirebaseApplication('https://tweeflix-3a7f6.firebaseio.com', None)

# %%
firebase.delete('/query_1', 'total')
firebase.put('','/query_1/total', 0)

while True:
    time.sleep(1)
    
    query_1 = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _1 IS NOT NULL") 
    query_1_list = query_1.collect()  
    
    total = int(firebase.get('', '/query_1/total'))
    total = total + int(query_1_list[0].cnt)
    firebase.put('','/query_1/total', total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-cb7ab678dea5> in <module>
#       6
#       7     query_1 = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _1 IS NOT NULL")
# ----> 8     query_1_list = query_1.collect()
#       9
#      10     total = int(firebase.get('', '/query_1/total'))
#
# C:\Spark\spark-2.4.4-bin-hadoop2.7\python\pyspark\sql\dataframe.py in collect(self)
#     532         """
#     533         with SCCallSiteSync(self._sc) as css:
# --> 534             sock_info = self._jdf.collectToPython()
#     535         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     536
#
# C:\Spark\spark-2.4.4-bin-hadoop2.7\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# ...

# %%
firebase.delete('/query_2', '')
firebase.put('','/query_2/business_and_finance', 0)
firebase.put('','/query_2/criminal_justice', 0)
firebase.put('','/query_2/health_care', 0)
firebase.put('','/query_2/policy_and_politics', 0)
firebase.put('','/query_2/science_and_health', 0)

while True:
    time.sleep(1)
    
    query_2 = sqlContext.sql("SELECT cast(count(*) as int) as cnt, _6 as categories FROM tweets WHERE _6 IS NOT NULL GROUP BY _6")
    query_2_list = query_2.collect()
    
    for item in query_2_list:
        if item.categories == ' Business & Finance ':
            total = int(firebase.get('', '/query_2/business_and_finance'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/business_and_finance', total) 
            
        if item.categories == ' Criminal Justice ':
            total = int(firebase.get('', '/query_2/criminal_justice'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/criminal_justice', total) 
        
        if item.categories == ' Health Care ':
            total = int(firebase.get('', '/query_2/health_care'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/health_care', total) 
        
        if item.categories == ' Policy and Politics ':
            total = int(firebase.get('', '/query_2/policy_and_politics'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/policy_and_politics', total) 
        
        if item.categories == ' Science & Health ':
            total = int(firebase.get('', '/query_2/science_and_health'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/science_and_health', total)

# %%
firebase.delete('/query_3', '')
firebase.put('','/query_3/hashtags', '')

while True:
    time.sleep(1)
    
    query_3 = sqlContext.sql("SELECT _7 as hashtags FROM tweets") 
    query_3_list = query_3.select('hashtags').collect()
    
    for item in query_3_list:
        hashtags = str(firebase.get('', '/query_3/hashtags'))
        hashtags = hashtags + str(item.hashtags)
        firebase.put('','/query_3/hashtags', hashtags)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9cf1f643045f> in <module>
#       6
#       7     query_3 = sqlContext.sql("SELECT _7 as hashtags FROM tweets")
# ----> 8     query_3_list = query_3.select('hashtags').collect()
#       9
#      10     for item in query_3_list:
#
# C:\Spark\spark-2.4.4-bin-hadoop2.7\python\pyspark\sql\dataframe.py in collect(self)
#     532         """
#     533         with SCCallSiteSync(self._sc) as css:
# --> 534             sock_info = self._jdf.collectToPython()
#     535         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     536
#
# C:\Spark\spark-2.4.4-bin-hadoop2.7\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
# ...

# %%
firebase.delete('/query_4', '')
firebase.put('','/query_4/cholera', 0)
firebase.put('','/query_4/flu', 0)
firebase.put('','/query_4/cancer', 0)
firebase.put('','/query_4/diabetes', 0)
firebase.put('','/query_4/hiv', 0)

while True:
    
#     cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cholera%'")
    cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%a%'")
    cholera_list = cholera_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_4/cholera'))
    total = total + int(cholera_list[0].cnt)
    firebase.put('','/query_4/cholera', total) 
    
#     flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%flu%' OR _2 LIKE 'influenza'")
    flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%b%'")
    flu_list = flu_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_4/flu'))
    total = total + int(flu_list[0].cnt)
    firebase.put('','/query_4/flu', total) 
    
#     cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cancer%'")
    cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%c%'")
    cancer_list = cancer_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_4/cancer'))
    total = total + int(cancer_list[0].cnt)
    firebase.put('','/query_4/cancer', total) 
    
#     diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%diabetes%'")
    diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%d%'")
    diabetes_list = diabetes_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_4/diabetes'))
    total = total + int(diabetes_list[0].cnt)
    firebase.put('','/query_4/diabetes', total) 
    
#     hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%hiv%' OR _2 LIKE '%aids%'")
    hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%e%'")
    hiv_list = hiv_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_4/hiv'))
    total = total + int(hiv_list[0].cnt)
    firebase.put('','/query_4/hiv', total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-33e3fdade944> in <module>
#      28     cancer_list = cancer_source.select('cnt').collect()
#      29     total = 0
# ---> 30     total = int(firebase.get('', '/query_4/cancer'))
#      31     total = total + int(cancer_list[0].cnt)
#      32     firebase.put('','/query_4/cancer', total)
#
# c:\users\kaphc\appdata\local\programs\python\python37\lib\site-packages\firebase\decorators.py in wrapped(*args, **kwargs)
#      17             connection.timeout = timeout
#      18             connection.headers.update({'Content-type': 'application/json'})
# ---> 19             return f(*args, **kwargs)
#      20         return wraps(f)(wrapped)
#      21     return wrapper
#
# c:\users\kaphc\appdata\local\programs\python\python37\lib\site-packages\firebase\firebase.py in get(self, url, name, connection, params, headers)
# ...

# %%
firebase.delete('/query_5', '')
firebase.put('','/query_5/cholera_pos', 0)
firebase.put('','/query_5/cholera_neg', 0)
firebase.put('','/query_5/flu_pos', 0)
firebase.put('','/query_5/flu_neg', 0)
firebase.put('','/query_5/cancer_pos', 0)
firebase.put('','/query_5/cancer_neg', 0)
firebase.put('','/query_5/diabetes_pos', 0)
firebase.put('','/query_5/diabetes_neg', 0)
firebase.put('','/query_5/hiv_pos', 0)
firebase.put('','/query_5/hiv_neg', 0)

while True:
    
#     cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cholera%'")
    cholera_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%a%' AND _3 LIKE '%1%'")
    cholera_pos_list = cholera_pos_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/cholera_pos'))
    total = total + int(cholera_pos_list[0].cnt)
    firebase.put('','/query_5/cholera_pos', total) 
    
#     cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cholera%'")
    cholera_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%a%' AND _3 LIKE '%0%'")
    cholera_neg_list = cholera_neg_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/cholera_neg'))
    total = total + int(cholera_neg_list[0].cnt)
    firebase.put('','/query_5/cholera_neg', total) 
    
#     flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%flu%' OR _2 LIKE 'influenza'")
    flu_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%b%' AND _3 LIKE '%1%'")
    flu_pos_list = flu_pos_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/flu_pos'))
    total = total + int(flu_pos_list[0].cnt)
    firebase.put('','/query_5/flu_pos', total) 
    
#     flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%flu%' OR _2 LIKE 'influenza'")
    flu_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%b%' AND _3 LIKE '%0%'")
    flu_neg_list = flu_neg_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/flu_neg'))
    total = total + int(flu_neg_list[0].cnt)
    firebase.put('','/query_5/flu_neg', total) 
    
#     cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cancer%'")
    cancer_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%c%' AND _3 LIKE '%1%'")
    cancer_pos_list = cancer_pos_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/cancer_pos'))
    total = total + int(cancer_pos_list[0].cnt)
    firebase.put('','/query_5/cancer_pos', total) 

#     cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cancer%'")
    cancer_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%c%' AND _3 LIKE '%0%'")
    cancer_neg_list = cancer_neg_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/cancer_neg'))
    total = total + int(cancer_neg_list[0].cnt)
    firebase.put('','/query_5/cancer_neg', total) 
    
#     diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%diabetes%'")
    diabetes_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%d%' AND _3 LIKE '%1%'")
    diabetes_pos_list = diabetes_pos_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/diabetes_pos'))
    total = total + int(diabetes_pos_list[0].cnt)
    firebase.put('','/query_5/diabetes_pos', total) 
    
#     diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%diabetes%'")
    diabetes_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%d%' AND _3 LIKE '%0%'")
    diabetes_neg_list = diabetes_neg_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/diabetes_neg'))
    total = total + int(diabetes_neg_list[0].cnt)
    firebase.put('','/query_5/diabetes_neg', total) 
    
#     hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%hiv%' OR _2 LIKE '%aids%'")
    hiv_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%e%' AND _3 LIKE '%1%'")
    hiv_pos_list = hiv_pos_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/hiv_pos'))
    total = total + int(hiv_pos_list[0].cnt)
    firebase.put('','/query_5/hiv_pos', total) 
    
#     hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%hiv%' OR _2 LIKE '%aids%'")
    hiv_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%e%' AND _3 LIKE '%0%'")
    hiv_neg_list = hiv_neg_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/hiv_neg'))
    total = total + int(hiv_neg_list[0].cnt)
    firebase.put('','/query_5/hiv_neg', total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-7a07a7a7dcfa> in <module>
#      47 #     cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cancer%'")
#      48     cancer_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%c%' AND _3 LIKE '%1%'")
# ---> 49     cancer_pos_list = cancer_pos_source.select('cnt').collect()
#      50     total = 0
#      51     total = int(firebase.get('', '/query_5/cancer_pos'))
#
# C:\Spark\spark-2.4.4-bin-hadoop2.7\python\pyspark\sql\dataframe.py in collect(self)
#     532         """
#     533         with SCCallSiteSync(self._sc) as css:
# --> 534             sock_info = self._jdf.collectToPython()
#     535         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     536
#
# ...

# %%
firebase.delete('/query_1', 'total')
firebase.put('','/query_1/total', 0)

firebase.delete('/query_2', '')
firebase.put('','/query_2/business_and_finance', 0)
firebase.put('','/query_2/criminal_justice', 0)
firebase.put('','/query_2/health_care', 0)
firebase.put('','/query_2/policy_and_politics', 0)
firebase.put('','/query_2/science_and_health', 0)

firebase.delete('/query_3', '')
firebase.put('','/query_3/hashtags', '')

firebase.delete('/query_4', '')
firebase.put('','/query_4/cholera', 0)
firebase.put('','/query_4/flu', 0)
firebase.put('','/query_4/cancer', 0)
firebase.put('','/query_4/diabetes', 0)
firebase.put('','/query_4/hiv', 0)

firebase.delete('/query_5', '')
firebase.put('','/query_5/cholera_pos', 0)
firebase.put('','/query_5/cholera_neg', 0)
firebase.put('','/query_5/flu_pos', 0)
firebase.put('','/query_5/flu_neg', 0)
firebase.put('','/query_5/cancer_pos', 0)
firebase.put('','/query_5/cancer_neg', 0)
firebase.put('','/query_5/diabetes_pos', 0)
firebase.put('','/query_5/diabetes_neg', 0)
firebase.put('','/query_5/hiv_pos', 0)
firebase.put('','/query_5/hiv_neg', 0)

while True:
    time.sleep(1)
    
    
    
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Query-1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    query_1 = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _1 IS NOT NULL") 
    query_1_list = query_1.collect()  
    
    total = int(firebase.get('', '/query_1/total'))
    total = total + int(query_1_list[0].cnt)
    firebase.put('','/query_1/total', total) 

    
    
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Query-2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    query_2 = sqlContext.sql("SELECT cast(count(*) as int) as cnt, _4 as categories FROM tweets WHERE _4 IS NOT NULL GROUP BY _4")
    query_2_list = query_2.collect()
    
    for item in query_2_list:
        if item.categories == ' Business & Finance ':
            total = int(firebase.get('', '/query_2/business_and_finance'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/business_and_finance', total) 
            
        if item.categories == ' Criminal Justice ':
            total = int(firebase.get('', '/query_2/criminal_justice'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/criminal_justice', total) 
        
        if item.categories == ' Health Care ':
            total = int(firebase.get('', '/query_2/health_care'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/health_care', total) 
        
        if item.categories == ' Policy and Politics ':
            total = int(firebase.get('', '/query_2/policy_and_politics'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/policy_and_politics', total) 
        
        if item.categories == ' Science & Health ':
            total = int(firebase.get('', '/query_2/science_and_health'))
            total = total + int(item.cnt)
            firebase.put('','/query_2/science_and_health', total) 
    
    
    
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Query-3 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    query_3 = sqlContext.sql("SELECT _5 as hashtags FROM tweets") 
    query_3_list = query_3.select('hashtags').collect()
    
    for item in query_3_list:
        hashtags = str(firebase.get('', '/query_3/hashtags'))
        hashtags = hashtags + str(item.hashtags)
        firebase.put('','/query_3/hashtags', hashtags) 

        
        
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Query-4 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cholera%'")
    cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%a%'")
    cholera_list = cholera_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_4/cholera'))
    total = total + int(cholera_list[0].cnt)
    firebase.put('','/query_4/cholera', total) 
    
#     flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%flu%' OR _2 LIKE 'influenza'")
    flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%b%'")
    flu_list = flu_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_4/flu'))
    total = total + int(flu_list[0].cnt)
    firebase.put('','/query_4/flu', total) 
    
#     cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cancer%'")
    cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%c%'")
    cancer_list = cancer_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_4/cancer'))
    total = total + int(cancer_list[0].cnt)
    firebase.put('','/query_4/cancer', total) 
    
#     diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%diabetes%'")
    diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%d%'")
    diabetes_list = diabetes_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_4/diabetes'))
    total = total + int(diabetes_list[0].cnt)
    firebase.put('','/query_4/diabetes', total) 
    
#     hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%hiv%' OR _2 LIKE '%aids%'")
    hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%e%'")
    hiv_list = hiv_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_4/hiv'))
    total = total + int(hiv_list[0].cnt)
    firebase.put('','/query_4/hiv', total) 
    
    
    
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Query-5 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cholera%'")
    cholera_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%a%' AND _3 LIKE '%1%'")
    cholera_pos_list = cholera_pos_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/cholera_pos'))
    total = total + int(cholera_pos_list[0].cnt)
    firebase.put('','/query_5/cholera_pos', total) 
    
#     cholera_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cholera%'")
    cholera_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%a%' AND _3 LIKE '%0%'")
    cholera_neg_list = cholera_neg_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/cholera_neg'))
    total = total + int(cholera_neg_list[0].cnt)
    firebase.put('','/query_5/cholera_neg', total) 
    
#     flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%flu%' OR _2 LIKE 'influenza'")
    flu_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%b%' AND _3 LIKE '%1%'")
    flu_pos_list = flu_pos_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/flu_pos'))
    total = total + int(flu_pos_list[0].cnt)
    firebase.put('','/query_5/flu_pos', total) 
    
#     flu_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%flu%' OR _2 LIKE 'influenza'")
    flu_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%b%' AND _3 LIKE '%0%'")
    flu_neg_list = flu_neg_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/flu_neg'))
    total = total + int(flu_neg_list[0].cnt)
    firebase.put('','/query_5/flu_neg', total) 
    
#     cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cancer%'")
    cancer_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%c%' AND _3 LIKE '%1%'")
    cancer_pos_list = cancer_pos_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/cancer_pos'))
    total = total + int(cancer_pos_list[0].cnt)
    firebase.put('','/query_5/cancer_pos', total) 

#     cancer_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%cancer%'")
    cancer_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%c%' AND _3 LIKE '%0%'")
    cancer_neg_list = cancer_neg_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/cancer_neg'))
    total = total + int(cancer_neg_list[0].cnt)
    firebase.put('','/query_5/cancer_neg', total) 
    
#     diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%diabetes%'")
    diabetes_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%d%' AND _3 LIKE '%1%'")
    diabetes_pos_list = diabetes_pos_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/diabetes_pos'))
    total = total + int(diabetes_pos_list[0].cnt)
    firebase.put('','/query_5/diabetes_pos', total) 
    
#     diabetes_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%diabetes%'")
    diabetes_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%d%' AND _3 LIKE '%0%'")
    diabetes_neg_list = diabetes_neg_source.select('cnt').collect()
    total = 0
    total = int(firebase.get('', '/query_5/diabetes_neg'))
    total = total + int(diabetes_neg_list[0].cnt)
    firebase.put('','/query_5/diabetes_neg', total) 
    
#     hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%hiv%' OR _2 LIKE '%aids%'")
    hiv_pos_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%e%' AND _3 LIKE '%1%'")
    hiv_pos_list = hiv_pos_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/hiv_pos'))
    total = total + int(hiv_pos_list[0].cnt)
    firebase.put('','/query_5/hiv_pos', total) 
    
#     hiv_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%hiv%' OR _2 LIKE '%aids%'")
    hiv_neg_source = sqlContext.sql("SELECT count(*) as cnt FROM tweets WHERE _2 LIKE '%e%' AND _3 LIKE '%0%'")
    hiv_neg_list = hiv_neg_source.select('cnt').collect()    
    total = 0
    total = int(firebase.get('', '/query_5/hiv_neg'))
    total = total + int(hiv_neg_list[0].cnt)
    firebase.put('','/query_5/hiv_neg', total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-4edfd9ec611c> in <module>
#      62
#      63         if item.categories == ' Health Care ':
# ---> 64             total = int(firebase.get('', '/query_2/health_care'))
#      65             total = total + int(item.cnt)
#      66             firebase.put('','/query_2/health_care', total)
#
# c:\users\kaphc\appdata\local\programs\python\python37\lib\site-packages\firebase\decorators.py in wrapped(*args, **kwargs)
#      17             connection.timeout = timeout
#      18             connection.headers.update({'Content-type': 'application/json'})
# ---> 19             return f(*args, **kwargs)
#      20         return wraps(f)(wrapped)
#      21     return wrapper
#
# c:\users\kaphc\appdata\local\programs\python\python37\lib\site-packages\firebase\firebase.py in get(self, url, name, connection, params, headers)
# ...
